# %%
import pandas as pd
import pandas_profiling as pdp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b26df745f5cb> in <module>
#       1 import pandas as pd
# ----> 2 import pandas_profiling as pdp
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\profile_report.py in <module>
#      25 from pandas_profiling.report.presentation.core import Root
# ...
